# %%
import pandas as pd
import numpy as np

data = pd.read_csv("C:\\Users\\jit16\\Downloads\\Practice DSBDA\\Student_data.csv")
df = pd.DataFrame(data)

# %%
df
# Out:
#     Sr No    Name  Age  Gender  Roll No Subject  Marks Grade
# 0       1   Aarav   20    Male      101   DSBDA     85     A
# 1       2    Diya   21  Female      102     CNS     78     B
# 2       3  Vihaan   19    Male      103     OOP     92    A+
# 3       4   Anaya   20  Female      104      WT     67     C
# 4       5  Aditya   22    Male      105   DSBDA     74     B
# 5       6    Isha   21  Female      106     CNS     88     A
# 6       7   Rohan   20    Male      107     OOP     59     D
# 7       8   Meera   19  Female      108      WT     95    A+
# 8       9   Karan   22    Male      109   DSBDA     81     A
# 9      10   Priya   20  Female      110     CNS     72     B
# 10     11   Arjun   21    Male      111     OOP     65     C
# 11     12   Sneha   19  Female      112      WT     90    A+
# 12     13     Raj   20    Male      113   DSBDA     55     D
# 13     14   Kavya   22  Female      114     CNS     84     A
# ...

# %%
df.isnull().sum()
# Out:
# Sr No      0
# Name       0
# Age        0
# Gender     0
# Roll No    0
# Subject    0
# Marks      0
# Grade      0
# dtype: int64

# %%
df.isnull()
# Out:
#     Sr No   Name    Age  Gender  Roll No  Subject  Marks  Grade
# 0   False  False  False   False    False    False  False  False
# 1   False  False  False   False    False    False  False  False
# 2   False  False  False   False    False    False  False  False
# 3   False  False  False   False    False    False  False  False
# 4   False  False  False   False    False    False  False  False
# 5   False  False  False   False    False    False  False  False
# 6   False  False  False   False    False    False  False  False
# 7   False  False  False   False    False    False  False  False
# 8   False  False  False   False    False    False  False  False
# 9   False  False  False   False    False    False  False  False
# 10  False  False  False   False    False    False  False  False
# 11  False  False  False   False    False    False  False  False
# 12  False  False  False   False    False    False  False  False
# 13  False  False  False   False    False    False  False  False
# ...

# %%
df.dtypes
# Out:
# Sr No      int64
# Name         str
# Age        int64
# Gender       str
# Roll No    int64
# Subject      str
# Marks      int64
# Grade        str
# dtype: object

# %%
df['Age']=df['Age'].astype('float64')

# %%
df['Marks']=df['Marks'].astype('float64')

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df.head()
# Out:
#    Sr No    Name   Age  Gender  Roll No Subject  Marks Grade
# 0      1   Aarav  20.0    Male      101   DSBDA   85.0     A
# 1      2    Diya  21.0  Female      102     CNS   78.0     B
# 2      3  Vihaan  19.0    Male      103     OOP   92.0    A+
# 3      4   Anaya  20.0  Female      104      WT   67.0     C
# 4      5  Aditya  22.0    Male      105   DSBDA   74.0     B

# %%
df["Marks"].fillna(df["Marks"].median())
# Out:
# 0     85.0
# 1     78.0
# 2     92.0
# 3     67.0
# 4     74.0
# 5     88.0
# 6     59.0
# 7     95.0
# 8     81.0
# 9     72.0
# 10    65.0
# 11    90.0
# 12    55.0
# 13    84.0
# 14    76.0
# 15    69.0
# 16    93.0
# 17    87.0
# 18    61.0
# 19    79.0
# Name: Marks, dtype: float64

# %%
df
# Out:
#     Sr No    Name   Age  Gender  Roll No Subject  Marks Grade
# 0       1   Aarav  20.0    Male      101   DSBDA   85.0     A
# 1       2    Diya  21.0  Female      102     CNS   78.0     B
# 2       3  Vihaan  19.0    Male      103     OOP   92.0    A+
# 3       4   Anaya  20.0  Female      104      WT   67.0     C
# 4       5  Aditya  22.0    Male      105   DSBDA   74.0     B
# 5       6    Isha  21.0  Female      106     CNS   88.0     A
# 6       7   Rohan  20.0    Male      107     OOP   59.0     D
# 7       8   Meera  19.0  Female      108      WT   95.0    A+
# 8       9   Karan  22.0    Male      109   DSBDA   81.0     A
# 9      10   Priya  20.0  Female      110     CNS   72.0     B
# 10     11   Arjun  21.0    Male      111     OOP   65.0     C
# 11     12   Sneha  19.0  Female      112      WT   90.0    A+
# 12     13     Raj  20.0    Male      113   DSBDA   55.0     D
# 13     14   Kavya  22.0  Female      114     CNS   84.0     A
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(x=df["Age"])
# Out:
# <Axes: xlabel='Age'>

# %%
Q1 = df['Age'].quantile(0.25)

# %%
Q1
# Out:
# np.float64(20.0)

# %%
Q2 = df['Age'].quantile(0.5)

# %%
Q2
# Out:
# np.float64(20.0)

# %%
Q3 =df['Age'].quantile(0.75)

# %%
IQR= Q3- Q1

# %%
IQR
# Out:
# np.float64(1.0)

# %%
lower_bound = Q1 - 1.5 * IQR
lower_bound
# Out:
# np.float64(18.5)

# %%
uper_bound= Q3 + 1.5 * IQR
uper_bound
# Out:
# np.float64(22.5)

# %%
df['Age']= df['Age'].clip(lower_bound, uper_bound)

# %%
df
# Out:
#     Sr No    Name   Age  Gender  Roll No Subject  Marks Grade
# 0       1   Aarav  20.0    Male      101   DSBDA   85.0     A
# 1       2    Diya  21.0  Female      102     CNS   78.0     B
# 2       3  Vihaan  19.0    Male      103     OOP   92.0    A+
# 3       4   Anaya  20.0  Female      104      WT   67.0     C
# 4       5  Aditya  22.0    Male      105   DSBDA   74.0     B
# 5       6    Isha  21.0  Female      106     CNS   88.0     A
# 6       7   Rohan  20.0    Male      107     OOP   59.0     D
# 7       8   Meera  19.0  Female      108      WT   95.0    A+
# 8       9   Karan  22.0    Male      109   DSBDA   81.0     A
# 9      10   Priya  20.0  Female      110     CNS   72.0     B
# 10     11   Arjun  21.0    Male      111     OOP   65.0     C
# 11     12   Sneha  19.0  Female      112      WT   90.0    A+
# 12     13     Raj  20.0    Male      113   DSBDA   55.0     D
# 13     14   Kavya  22.0  Female      114     CNS   84.0     A
# ...
